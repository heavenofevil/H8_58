# %%
# !pip install Pillow

# %%
from PIL import Image 

infile = "koala.png"

im = Image.open(infile)
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=274x184 at 0x1B191E26250>
# koala.png JPEG 274x184 RGB
